# %%
#導入需要的依賴包
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # #統計預測圖
# seaborn.relplot() 是一個非常好用的繪圖指令, 可以一次把數個變數的關係呈現在一張圖表上.
#
# `load_dataset` looks for online csv files on https://github.com/mwaskom/seaborn-data. Here's the docstring:<br>
#
# Load a dataset from the online repository (requires internet).<br>
#
# >Parameters
#
# >name : str Name of the dataset (name.csv on https://github.com/mwaskom/seaborn-data). You can obtain list of available datasets using func:get_dataset_names<br>
# kws : dict, optional Passed to pandas.read_csv

# %%
#加載sns內置數據集 
tips = sns.load_dataset('tips')  #基本上就是在此網址(https://github.com/mwaskom/seaborn-data)
                                 #中的csv檔才能用
sns.set(color_codes = True)
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# 內建數據集-tips數據集
# > 關於數據集，total_bill是消費總金額，tip是小費，size指用餐人數。

# %%
NBA = sns.load_dataset('C:/Users/he3713/Desktop/NTU_cool_[ML449]/UNIT 2 -Data Analysis Package/Unit02/data/NBA_season1718_salary.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 NBA = sns.load_dataset('C:/Users/he3713/Desktop/NTU_cool_[ML449]/UNIT 2 -Data Analysis Package/Unit02/data/NBA_season1718_salary.csv')
#
# File ~/miniforge3/envs/HermesML/lib/python3.9/site-packages/seaborn/utils.py:573, in load_dataset(name, cache, data_home, **kws)
#     571 if not os.path.exists(cache_path):
#     572     if name not in get_dataset_names():
# --> 573         raise ValueError(f"'{name}' is not one of the example datasets.")
#     574     urlretrieve(url, cache_path)
#     575 full_path = cache_path
#
# ValueError: 'C:/Users/he3713/Desktop/NTU_cool_[ML449]/UNIT 2 -Data Analysis Package/Unit02/data/NBA_season1718_salary.csv' is not one of the example datasets.

# %%
sns.relplot(x='total_bill',y='tip',col='time',
            hue='smoker',style='smoker',size='size',data=tips)
plt.show()

# %% [markdown]
# # #單變量分析繪圖（直方圖、條形圖）
# > Dataset: NBA_season1718_salary.csv<br>
# ref:https://www.kaggle.com/koki25ando/salary

# %%
data = pd.read_csv("/mnt/c/Users/he3713/Unit02/data/NBA_season1718_salary.csv")
data
# Out:
#      Unnamed: 0          Player   Tm  season17_18
# 0             1   Stephen Curry  GSW   34682550.0
# 1             2    LeBron James  CLE   33285709.0
# 2             3    Paul Millsap  DEN   31269231.0
# 3             4  Gordon Hayward  BOS   29727900.0
# 4             5   Blake Griffin  DET   29512900.0
# ..          ...             ...  ...          ...
# 568         569      Quinn Cook  NOP      25000.0
# 569         570   Chris Johnson  HOU      25000.0
# 570         571      Beno Udrih  DET      25000.0
# 571         572   Joel Bolomboy  MIL      22248.0
# 572         573    Jarell Eddie  CHI      17224.0
#
# [573 rows x 4 columns]

# %%
#對讀進來的數據按薪資降序排序並取前10條數據
salary_top10 = (data.sort_values('season17_18', ascending=False)).head(10)
salary_top10
# Out:
#    Unnamed: 0             Player   Tm  season17_18
# 0           1      Stephen Curry  GSW   34682550.0
# 1           2       LeBron James  CLE   33285709.0
# 2           3       Paul Millsap  DEN   31269231.0
# 3           4     Gordon Hayward  BOS   29727900.0
# 4           5      Blake Griffin  DET   29512900.0
# 5           6         Kyle Lowry  TOR   28703704.0
# 6           7  Russell Westbrook  OKC   28530608.0
# 7           8        Mike Conley  MEM   28530608.0
# 8           9       James Harden  HOU   28299399.0
# 9          10      DeMar DeRozan  TOR   27739975.0

# %%
#取出球員列數據，作為條形圖橫坐標
player=salary_top10['Player']
season_salary=salary_top10['season17_18']

#取出球員薪資列，作為條形圖縱坐標

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=45)
plt.ylim(season_salary.min()*0.5, season_salary.max()*1.05)
sns.barplot(x=player,y=season_salary,data=salary_top10,ci=68,palette='deep')
plt.show()

# %% [markdown]
# ## Result
#
# 從條形圖中不難看出，勇士隊的當家球星curry資最高，將近達到3500萬美元，位居第二的是勒布朗詹姆斯，也是在3300萬美元以上。上面的條形圖是按球員作為橫坐標，下面我們按球隊匯總，看看哪個球隊的薪資總額最高。

# %% [markdown]
# # 練習 - 彙總球隊薪資繪製成直方圖
# 按球隊匯總，看看哪個球隊的薪資總額最高。

# %%
salary_by_team = data.groupby(by='Tm').sum().drop(['Player'],axis=1)
salary_by_team
# Out:
#      Unnamed: 0  season17_18
# Tm
# ATL        9324  100217797.0
# BOS        4712  115009962.0
# BRK        4953   96039772.0
# CHI        7551   89425042.0
# CHO        3061  117228164.0
# CLE        2979  137288549.0
# DAL        7636   85821361.0
# DEN        3624  107889099.0
# DET        5639  120086105.0
# GSW        3892  137494845.0
# HOU        7363  119024081.0
# IND        5653   94429791.0
# LAC        5891  118907163.0
# LAL        7241  105355450.0
# MEM        6557  110104061.0
# MIA        4392  131222624.0
# MIL        6485  120686318.0
# MIN        3482  117468554.0
# NOP        6775  119725571.0
# NYK        6024  107855405.0
# OKC        3246  134294056.0
# ORL        4567   96925954.0
# PHI        6194  100794278.0
# PHO        6290   94818333.0
# POR        5307  119108924.0
# SAC        5164   95627528.0
# SAS        4467  116153554.0
# TOR        5109  116528796.0
# UTA        5855  107465014.0
# WAS        5018  124179842.0

# %%
#先將資料集用groupby根據球隊分別匯總
salary_by_team=(data.groupby(by='Tm').sum().sort_values('season17_18', ascending=False)).drop(['Player'],axis=1).reset_index().head(10)
print(salary_by_team)
team=salary_by_team['Tm']
season=salary_by_team['season17_18']
sns.barplot(x=team,y=season,data=salary_by_team,ci=68,palette='deep')
plt.show()
# Out:
#     Tm  Unnamed: 0  season17_18
# 0  GSW        3892  137494845.0
# 1  CLE        2979  137288549.0
# 2  OKC        3246  134294056.0
# 3  MIA        4392  131222624.0
# 4  WAS        5018  124179842.0
# 5  MIL        6485  120686318.0
# 6  DET        5639  120086105.0
# 7  NOP        6775  119725571.0
# 8  POR        5307  119108924.0
# 9  HOU        7363  119024081.0

# %%
import scipy.stats as state
x = np.random.gamma(6, size = 200)
sns.distplot(x, kde=False, fit=state.gamma)
mean, cov = [0,1],[(1,0.5),(0.5,1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data,columns=['x','y'])
sns.jointplot(x='x',y='y',data=df)
plt.show()

# %% [markdown]
# # #seaborn回歸分析繪圖（regplot）

# %%
#導入依賴包 
# %matplotlib inline 
import numpy as np 
import pandas as pd 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
import seaborn as sns 
#加載sns內置數據集 
tips = sns.load_dataset('tips')  
sns.set(color_codes = True)
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# 內建數據集-tips數據集
# > 關於數據集，total_bill是消費總金額，tip是小費，size指用餐人數。

# %%
sns.regplot(data=tips,x='total_bill',y='tip',line_kws={'color':'r'})
plt.show()

# %% [markdown]
# # [練習]看看其他變量和小費之間的關係。

# %%
sns.regplot(data=tips,x='size',y='tip',x_jitter=0.3,line_kws={'color':'r'})
plt.show()

# %%
#導入依賴包 %matplotlib inline 
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set(style="whitegrid", color_codes=True) 
tips = sns.load_dataset("tips")

# %%
sns.distplot(tips['total_bill'])
sns.distplot(tips['tip'])
plt.show()

# %% [markdown]
# # #散點圖（分布散點、分簇散點圖）

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
plt.show()

# %%
import seaborn as sns 
sns.set(style="whitegrid", color_codes=True) 
sns.stripplot(x='total_bill',y='tip',data=tips,palette='deep')
plt.show()

# %% [markdown]
# 從上面的圖中可以看到，stripplot參數中的x是橫軸數據（分類數據），y是縱軸數據（類型對應數據），由於我們將總金額作為分類，導致分類太多，橫軸數據根本看不清，所以我們重新傳參，分別看下性別和小費、時間和小費，用餐日期跟小費之間的數據分布。

# %%
sns.stripplot(x='sex',y='tip',data=tips, palette='deep')
plt.show()

# %%
sns.stripplot(x='day',y='tip',data=tips,palette='deep')
plt.show()

# %%
sns.stripplot(x='time',y='tip',data=tips, palette='deep')
plt.show()

# %%
sns.stripplot(x='smoker',y='tip',data=tips,palette='deep')
plt.show()

# %% [markdown]
# 因為jitter（數據抖動）這個參數的默認值是True,如果我們將其設置為False，效果如圖：

# %%
sns.stripplot(x='day',y='tip',jitter=False, data=tips, palette='deep')
plt.show()

# %%
sns.swarmplot(x='day',y='tip',data=tips, palette='deep')
plt.show()

# %% [markdown]
# 在stripplot函數中，我們只看了某一類別對應的數據，而沒有看類中對應其他類的數據分布，舉個例子，比如我們用stripplot看到男性和女性對應的小費數據，但是不知道男性和女性對應的數據中哪些是吸菸的，哪些是不吸菸的，對於這個問題這兩個函數都有一個hue參數，這裡我們就以分簇散點圖函數為例，演示下這個參數的效果，如圖：

# %%
sns.swarmplot(x='day',y='tip',data=tips, hue='sex',palette='deep')
plt.show()

# %% [markdown]
# 上面這個圖就很好的展示了不同性別在不同的星期中付小費數據的分布。

# %% [markdown]
# # #繪製盒圖、小提琴圖
# seaborn.boxplot()
# 這個函數主要是繪製出一個箱型圖來反映離群點數據。

# %%
sns.boxplot(x='tip',data=tips,palette='deep')
plt.show()

# %%
sns.boxplot(y='tip',data=tips,palette='deep')
plt.show()

# %%
sns.boxplot(y='tip',x='day',data=tips,palette='deep')
plt.show()

# %% [markdown]
# seaborn庫中的很多繪圖方法就是提前給你畫好模板，我們只需要把數據傳進去就得到相應的圖形，
# 基於此，我門是不是可以在同一個模板上同時繪製分簇圖和箱型圖呢？

# %%
sns.boxplot(x='day',y='total_bill',data=tips,palette='deep')
sns.swarmplot(x='day',y='total_bill',data=tips,color='.25')
plt.show()

# %%
sns.violinplot(x='day',y='tip',data=tips,palette='deep')
plt.show()

# %% [markdown]
# 小提琴圖即反映了數據的離群情況，同時也反映了數據的分布密度。<br>
# 此函數跟箱型圖一樣，也有hue參數，可以查看第二個分類屬性下的數據分布，如下：

# %%
sns.violinplot(x='day',y='tip',hue='sex',data=tips)
plt.show()

# %% [markdown]
# 可以看到，上面的小提琴圖是4對8個，即當設置hue參數為sex時，每個小提琴的數據集是一類數據，那有沒有辦法讓男性對應數據和女性對應數據都作為一個數據集繪製出一個小提琴圖，只是在一個圖中區分男性數據和女性數據呢？答案是肯定的，violinplot()函數提供了一個split參數，可以做到以上需求，如下：

# %%
sns.violinplot(x='day',y='tip',hue='sex',data=tips,split=True)
plt.show()

# %% [markdown]
# 除此以外，我們再來看一下inner參數，上面的小提琴圖中內部都是箱型圖，通過inner參數，我們可以設置其他類型，inner可選參數有：box、quartile(四分位)、point、stick。我們依次看下：

# %%
sns.violinplot(x='day',y='tip',hue='sex',data=tips,split=True, inner='box')
plt.show()

# %%
sns.violinplot(x='day',y='tip',hue='sex',data=tips,split=True, inner='quartile')
plt.show()

# %%
sns.violinplot(x='day',y='tip',hue='sex',data=tips,split=True, inner='point')
plt.show()

# %%
sns.violinplot(x='day',y='tip',hue='sex',data=tips,split=True, inner='stick')
plt.show()

# %% [markdown]
# # #結構化展示多維數據
# ***Visualizing the multidimensional relationships among the samples is as easy as calling sns.pairplot:***

# %%
sns.pairplot(tips,hue='sex',height=2.5)
plt.show()

# %% [markdown]
# 使用FacetGrid時，我們會通過一個pandas DataFrame以及控制圖形網格的行、列和顏色的變量名稱來初始化一個對象。這些維度變量（控制行、列和顏色的變量）應該是分類變量或者離散變量，然後這些變量的不同水平組合起來就構成了整個圖形的每一個子圖（facet，在這裡可以理解為我們維度拆解的最小粒度）
#
#
# 這一函數的目標是一步到位地提供一幅完整的成品圖，它在完成繪圖後還會對每個坐標軸添加注釋。

# %%
g=sns.FacetGrid(tips,col='time')
plt.show()

# %%
g.map(plt.hist,'tip')
plt.show()

# %%
g=sns.FacetGrid(tips,col='sex',hue='smoker')
g.map(plt.scatter,'total_bill','tip',alpha=.7)
g.add_legend()
plt.show()

# %% [markdown]
# 我們可以指定某個seaborn調色板，也可以通過字典將hue變量中的每個分類與其對應的matplotlib顏色傳遞給函數<br>
# （這樣就可以隨心所以使用大量的matplotlib支持的色彩）

# %%
pal=dict(Lunch='seagreen',Dinner='gray')
g=sns.FacetGrid(tips,hue='time',palette=pal,height=5)
g.map(plt.scatter,'total_bill','tip',s=50,alpha=.7,linewidth=0.5,edgecolor='white')
g.add_legend()
plt.show()

# %%
tips=sns.load_dataset('tips')
g=sns.PairGrid(tips)
g.map(plt.scatter)
plt.show()

# %% [markdown]
# map_diag()函數是繪製對角線上的單變量子圖，mag_offdiag是繪製對角線以外的兩個變量間的子圖。

# %%
g=sns.PairGrid(tips)
g=g.map_diag(plt.hist,edgecolor='w')
g=g.map_offdiag(plt.scatter,edgecolor='w',s=40)
plt.show()

# %% [markdown]
# # [練習]試著讀取自己的資料，繪製出多維數據圖表

# %%
tips=sns.load_dataset('iris')
g=sns.PairGrid(tips)
g.map(plt.scatter)
plt.show()
